# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # for scatter plot

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

# %% [markdown]
# # HEART FAILURE
#
# Cardiovascular diseases are the most common cause of deaths globally, taking an estimated 17.9 million lives each year, which accounts for 31% of all deaths worldwide. Heart failure is a common event caused by Cardiovascular diseases. It is characterized by the heart’s inability to pump an adequate supply of blood to the body. Without sufficient blood flow, all major body functions are disrupted. Heart failure is a condition or a collection of symptoms that weaken the heart.

# %% [markdown]
#  # **<span style="color:#6daa9f;">TABLE OF CONTENTS</span>**
#
#
# **IMPORTING LIBRARIES**
#
# **LOADING DATA**
#
# **DATA ANALYSIS**
#
# **DATA PREPROCESSING**
#
# **MODEL BUILDING**
#
# **CONCLUSIONS**
#
# # **<span style="color:#6daa9f;">IMPORTING LIBRARIES</span>**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from keras.layers import Dense, BatchNormalization, Dropout, LSTM
from keras.models import Sequential
from keras.utils import to_categorical
from keras import callbacks
from sklearn.metrics import precision_score, recall_score, confusion_matrix, classification_report, accuracy_score, f1_score

# %%
#These are the values we can change to find a difference between values and see the difference in the ANN

epochs_= 1000
batch_size_= 32
validation_= 0.2
test_Size_ = 0.2
random_state_=7

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# As we can see after we change the epoch to 1000 and we can see that accuracy is %88
#
# In the other %88 accuracy test we changed the batch size to 64 we can see the improvements
#
# but if we change the epoch to 1000 and batch size to 64 we can see  that accuracy drops drastically.

# %% [markdown]
# # **<span style="color:#6daa9f;">LOADING DATA</span>**

# %%
#loading data
data = pd.read_csv("/content/heart_failure_clinical_records_dataset.csv")
data.head()
# Out:
#     age  anaemia  creatinine_phosphokinase  diabetes  ejection_fraction  \
# 0  75.0        0                       582         0                 20
# 1  55.0        0                      7861         0                 38
# 2  65.0        0                       146         0                 20
# 3  50.0        1                       111         0                 20
# 4  65.0        1                       160         1                 20
#
#    high_blood_pressure  platelets  serum_creatinine  serum_sodium  sex  \
# 0                    1  265000.00               1.9           130    1
# 1                    0  263358.03               1.1           136    1
# 2                    0  162000.00               1.3           129    1
# 3                    0  210000.00               1.9           137    1
# 4                    0  327000.00               2.7           116    0
#
#    smoking  time  DEATH_EVENT
# 0        0     4            1
# 1        0     6            1
# 2        1     7            1
# 3        0     7            1
# 4        0     8            1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 299 entries, 0 to 298
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       299 non-null    float64
#  1   anaemia                   299 non-null    int64
#  2   creatinine_phosphokinase  299 non-null    int64
#  3   diabetes                  299 non-null    int64
#  4   ejection_fraction         299 non-null    int64
#  5   high_blood_pressure       299 non-null    int64
#  6   platelets                 299 non-null    float64
#  7   serum_creatinine          299 non-null    float64
#  8   serum_sodium              299 non-null    int64
#  9   sex                       299 non-null    int64
#  10  smoking                   299 non-null    int64
#  11  time                      299 non-null    int64
#  12  DEATH_EVENT               299 non-null    int64
# dtypes: float64(3), int64(10)
# memory usage: 30.5 KB

# %%
# Select two columns of data to use for the scatter plot
x = data['age']
y = data['serum_creatinine']# I used this parameters fo the best results for scatter plot

# Create a figure and axis
fig, ax = plt.subplots()

# Plot the data
ax.scatter(x, y)

# Add a title and axis labels
ax.set_title('Scatter Plot')
ax.set_xlabel('Age')
ax.set_ylabel('Serum creatinine')

# Show the plot
plt.show()

# %% [markdown]
# # Scatter Plot
#
# In this scatter plot we can clearly see how serum creatinine changes with age high on 50-70

# %%
    sns.violinplot(x='DEATH_EVENT',y='high_blood_pressure',data=data,color="blue")#I tried most of the parameters these were the most suitable ones for Violin plot
    plt.show()
    plt.title('Violin Plot')
    sns.violinplot(x='DEATH_EVENT',y='serum_creatinine',data=data)

# %% [markdown]
# # Violin Plot with Seaborne
#
# I tried the other dataset value combinations but these were the most usable ones
#
# In the first plot we can see how the high blood preassure leads to death event.
#
# Second plot  shows the death event and serum creatinine connection.

# %%
# create a pairplot
sns.pairplot(data, vars=["age", "serum_sodium", "ejection_fraction"])#These parameters was most suitable for this plot other ones where really messed uo the plot

# show the plot
plt.show()

# %% [markdown]
# # Pair Plot
# As we can see these parameters was most suitable for this plot other ones where really messed up the plot.
#
# This pair plot show how much does serum sordium changes when we age as we can see mostly between 20 and 40 it is at its peak.

# %%
sns.lmplot(x='age', y='serum_creatinine', data=data,
           fit_reg=True,  # Show regression line
           scatter_kws={'s': 20, 'alpha': 0.5, 'color': 'blue'},
           line_kws={'color': 'red', 'lw': 2, 'alpha': 0.7},
           height=5, aspect=1.5)

plt.title('Age vs Serum Creatinine')
plt.xlabel('Age')
plt.ylabel('Serum Creatinine')
plt.show()

# %% [markdown]
# **About the data:**
#
# * age: Age of the patient
# * anaemia: If the patient had the haemoglobin below the normal range
# * creatinine_phosphokinase: The level of the creatine phosphokinase in the blood in mcg/L
# * diabetes: If the patient was diabetic
# * ejection_fraction: Ejection fraction is a measurement of how much blood the left ventricle pumps out with each contraction
# * high_blood_pressure: If the patient had hypertension
# * platelets: Platelet count of blood in kiloplatelets/mL
# * serum_creatinine: The level of serum creatinine in the blood in mg/dL
# * serum_sodium: The level of serum sodium in the blood in mEq/L
# * sex: The sex of the patient
# * smoking: If the patient smokes actively or ever did in past
# * time: It is the time of the patient's follow-up visit for the disease in months
# * DEATH_EVENT: If the patient deceased during the follow-up period

# %% [markdown]
# all the attributes in here are vital to this ANN so we are not going to delete any of them but if we like to delete one of the attributes
#  we can use this code below,
#
# del data['Unnamed: 32']
# data.shape

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA ANALYSIS</span>**
#
# Steps in data analysis and visulisation:
#
# We begin our analysis by plotting a count plot of the targer attribute.
# A corelation matrix od the various attributes to examine the feature importance.

# %%
#first of all let us evaluate the target and find out if our data is imbalanced or not
cols= ["#6daa9f","#774571"]
sns.countplot(x= data["DEATH_EVENT"], palette= cols)

# %% [markdown]
# # Count Plot
#
#  Point to note is that there is an imbalance in the data.
#  We need to make a fix.

# %%
#Examaning a corelation matrix of all the features
cmap = sns.diverging_palette(275,150,  s=40, l=65, n=9)
corrmat = data.corr()
plt.subplots(figsize=(18,18))
sns.heatmap(corrmat,cmap= cmap,annot=True, square=True);

# %% [markdown]
# **Notable points:**
# * Time of the patient's follow-up visit for the disease is crucial in as initial diagnosis with cardiovascular issue and treatment reduces the chances of any fatality. It holds and inverse relation.
# * Ejection fraction is the second most important feature. It is quite expected as it is basically the efficiency of the heart.
# * Age of the patient is the third most correlated feature. Clearly as heart's functioning declines with ageing
#
# **Next, we will examine the count plot of age.**

# %%
#Evauating age distrivution
plt.figure(figsize=(20,12))
#colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
Days_of_week=sns.countplot(x=data['age'],data=data, hue ="DEATH_EVENT",palette = cols)
Days_of_week.set_title("Distribution Of Age", color="#774571")
# Out:
# Text(0.5, 1.0, 'Distribution Of Age')

# %% [markdown]
# ## Box Plot
#
# Looking at Distribution Of Age with the death event and trying to find when it happens.

# %%
# Boxen and swarm plot of some non binary features.
feature = ["age","creatinine_phosphokinase","ejection_fraction","platelets","serum_creatinine","serum_sodium", "time"]
for i in feature:
    plt.figure(figsize=(8,8))
    sns.swarmplot(x=data["DEATH_EVENT"], y=data[i], color="black", alpha=0.5)
    sns.boxenplot(x=data["DEATH_EVENT"], y=data[i], palette=cols)
    plt.show()
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/categorical.py:1296: UserWarning: 17.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# I spotted outliers on our dataset. I didn't remove them yet as it may lead to overfitting. Though we may end up with better statistics. In this case, with medical data, the outliers may be an important deciding factor.
#
# Next, we examine the kdeplot of time and age as they both are significant features.

# %%
sns.kdeplot(x=data["time"], y=data["age"], hue =data["DEATH_EVENT"], palette=cols)

# %%
data.describe().T
# Out:
#                           count           mean           std      min  \
# age                       299.0      60.833893     11.894809     40.0
# anaemia                   299.0       0.431438      0.496107      0.0
# creatinine_phosphokinase  299.0     581.839465    970.287881     23.0
# diabetes                  299.0       0.418060      0.494067      0.0
# ejection_fraction         299.0      38.083612     11.834841     14.0
# high_blood_pressure       299.0       0.351171      0.478136      0.0
# platelets                 299.0  263358.029264  97804.236869  25100.0
# serum_creatinine          299.0       1.393880      1.034510      0.5
# serum_sodium              299.0     136.625418      4.412477    113.0
# sex                       299.0       0.648829      0.478136      0.0
# smoking                   299.0       0.321070      0.467670      0.0
# time                      299.0     130.260870     77.614208      4.0
# DEATH_EVENT               299.0       0.321070      0.467670      0.0
#
#                                25%       50%       75%       max
# age                           51.0      60.0      70.0      95.0
# anaemia                        0.0       0.0       1.0       1.0
# creatinine_phosphokinase     116.5     250.0     582.0    7861.0
# diabetes                       0.0       0.0       1.0       1.0
# ejection_fraction             30.0      38.0      45.0      80.0
# high_blood_pressure            0.0       0.0       1.0       1.0
# platelets                 212500.0  262000.0  303500.0  850000.0
# serum_creatinine               0.9       1.1       1.4       9.4
# serum_sodium                 134.0     137.0     140.0     148.0
# sex                            0.0       1.0       1.0       1.0
# smoking                        0.0       0.0       1.0       1.0
# time                          73.0     115.0     203.0     285.0
# DEATH_EVENT                    0.0       0.0       1.0       1.0

# %% [markdown]
# # **<span style="color:#6daa9f;">DATA PREPROCESSING</span>**
#
# **Steps involved in Data Preprocessing**
# * Dropping the outliers based on data analysis
# * Assigning values to features as X and target as y
# * Perform the scaling of the features
# * Split test and training sets

# %%
#assigning values to features as X and target as y
X=data.drop(["DEATH_EVENT"],axis=1)
y=data["DEATH_EVENT"]

# %%
#Set up a standard scaler for the features
col_names = list(X.columns)
s_scaler = preprocessing.StandardScaler()
X_df= s_scaler.fit_transform(X)
X_df = pd.DataFrame(X_df, columns=col_names)
X_df.describe().T
# Out:
#                           count          mean       std       min       25%  \
# age                       299.0  5.703353e-16  1.001676 -1.754448 -0.828124
# anaemia                   299.0  1.009969e-16  1.001676 -0.871105 -0.871105
# creatinine_phosphokinase  299.0  0.000000e+00  1.001676 -0.576918 -0.480393
# diabetes                  299.0  9.060014e-17  1.001676 -0.847579 -0.847579
# ejection_fraction         299.0 -3.267546e-17  1.001676 -2.038387 -0.684180
# high_blood_pressure       299.0  0.000000e+00  1.001676 -0.735688 -0.735688
# platelets                 299.0  7.723291e-17  1.001676 -2.440155 -0.520870
# serum_creatinine          299.0  1.425838e-16  1.001676 -0.865509 -0.478205
# serum_sodium              299.0 -8.673849e-16  1.001676 -5.363206 -0.595996
# sex                       299.0 -8.911489e-18  1.001676 -1.359272 -1.359272
# smoking                   299.0 -1.188199e-17  1.001676 -0.687682 -0.687682
# time                      299.0 -1.901118e-16  1.001676 -1.629502 -0.739000
#
#                                50%       75%       max
# age                      -0.070223  0.771889  2.877170
# anaemia                  -0.871105  1.147968  1.147968
# creatinine_phosphokinase -0.342574  0.000166  7.514640
# diabetes                 -0.847579  1.179830  1.179830
# ejection_fraction        -0.007077  0.585389  3.547716
# high_blood_pressure      -0.735688  1.359272  1.359272
# platelets                -0.013908  0.411120  6.008180
# serum_creatinine         -0.284552  0.005926  7.752020
# serum_sodium              0.085034  0.766064  2.582144
# sex                       0.735688  0.735688  0.735688
# smoking                  -0.687682  1.454161  1.454161
# time                     -0.196954  0.938759  1.997038

# %%
#looking at the scaled features
colours =["#774571","#b398af","#f1f1f1" ,"#afcdc7", "#6daa9f"]
plt.figure(figsize=(20,10))
sns.boxenplot(data = X_df,palette = colours)
plt.xticks(rotation=90)
plt.show()

# %%
#spliting test and training sets
X_train, X_test, y_train,y_test = train_test_split(X_df,y,test_size=test_Size_,random_state=random_state_)

# %% [markdown]
# # **<span style="color:#6daa9f;">MODEL BUILDING</span>**
#
# In this project, we build an artificial neural network.
#
# **Following steps are involved in the model building**
# * Initialising the ANN
# * Defining by adding layers
# * Compiling the ANN
# * Train the ANN

# %%
early_stopping = callbacks.EarlyStopping(
    min_delta=0.001, # minimium amount of change to count as an improvement
    patience=20, # how many epochs to wait before stopping
    restore_best_weights=True)

# Initialising the NN
model = Sequential()

# layers
#Secret layer

model.add(Dense(units = 16, kernel_initializer = 'uniform', activation = 'relu', input_dim = 12))
#Secret layer
model.add(Dense(units = 8, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.25))
#Secret layer
model.add(Dense(units = 4, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dropout(0.5))
#Output layer
model.add(Dense(units = 1, kernel_initializer = 'uniform', activation = 'sigmoid'))
from keras.optimizers import SGD
# Compiling the ANN
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Train the ANN
history = model.fit(X_train, y_train, batch_size = batch_size_, epochs = epochs_,callbacks=[early_stopping], validation_split=validation_)
# Out:
# Epoch 1/1000
# 6/6 [==============================] - 2s 105ms/step - loss: 0.6928 - accuracy: 0.6387 - val_loss: 0.6921 - val_accuracy: 0.6875
# Epoch 2/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6919 - accuracy: 0.6492 - val_loss: 0.6910 - val_accuracy: 0.6875
# Epoch 3/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6911 - accuracy: 0.6492 - val_loss: 0.6899 - val_accuracy: 0.6875
# Epoch 4/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6903 - accuracy: 0.6492 - val_loss: 0.6888 - val_accuracy: 0.6875
# Epoch 5/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6894 - accuracy: 0.6492 - val_loss: 0.6877 - val_accuracy: 0.6875
# Epoch 6/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6884 - accuracy: 0.6492 - val_loss: 0.6866 - val_accuracy: 0.6875
# Epoch 7/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6876 - accuracy: 0.6492 - val_loss: 0.6855 - val_accuracy: 0.6875
# Epoch 8/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6865 - accuracy: 0.6492 - val_loss: 0.6842 - val_accuracy: 0.6875
# Epoch 9/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6860 - accuracy: 0.6492 - val_loss: 0.6830 - val_accuracy: 0.6875
# Epoch 10/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6843 - accuracy: 0.6492 - val_loss: 0.6817 - val_accuracy: 0.6875
# Epoch 11/1000
# 6/6 [==============================] - 0s 33ms/step - loss: 0.6837 - accuracy: 0.6492 - val_loss: 0.6803 - val_accuracy: 0.6875
# Epoch 12/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6826 - accuracy: 0.6492 - val_loss: 0.6788 - val_accuracy: 0.6875
# Epoch 13/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.6810 - accuracy: 0.6492 - val_loss: 0.6772 - val_accuracy: 0.6875
# Epoch 14/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6795 - accuracy: 0.6492 - val_loss: 0.6753 - val_accuracy: 0.6875
# Epoch 15/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.6774 - accuracy: 0.6492 - val_loss: 0.6732 - val_accuracy: 0.6875
# Epoch 16/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.6753 - accuracy: 0.6492 - val_loss: 0.6708 - val_accuracy: 0.6875
# Epoch 17/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.6728 - accuracy: 0.6492 - val_loss: 0.6680 - val_accuracy: 0.6875
# Epoch 18/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6712 - accuracy: 0.6597 - val_loss: 0.6650 - val_accuracy: 0.6875
# Epoch 19/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.6658 - accuracy: 0.6597 - val_loss: 0.6615 - val_accuracy: 0.6875
# Epoch 20/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.6645 - accuracy: 0.6754 - val_loss: 0.6575 - val_accuracy: 0.6875
# Epoch 21/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.6607 - accuracy: 0.7120 - val_loss: 0.6532 - val_accuracy: 0.7083
# Epoch 22/1000
# 6/6 [==============================] - 0s 23ms/step - loss: 0.6549 - accuracy: 0.6911 - val_loss: 0.6484 - val_accuracy: 0.7292
# Epoch 23/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.6513 - accuracy: 0.7068 - val_loss: 0.6431 - val_accuracy: 0.7292
# Epoch 24/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6459 - accuracy: 0.7330 - val_loss: 0.6372 - val_accuracy: 0.7500
# Epoch 25/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.6383 - accuracy: 0.7330 - val_loss: 0.6306 - val_accuracy: 0.7292
# Epoch 26/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.6242 - accuracy: 0.7906 - val_loss: 0.6231 - val_accuracy: 0.7083
# Epoch 27/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.6281 - accuracy: 0.7435 - val_loss: 0.6150 - val_accuracy: 0.8125
# Epoch 28/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.6158 - accuracy: 0.7592 - val_loss: 0.6063 - val_accuracy: 0.8125
# Epoch 29/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.6088 - accuracy: 0.7487 - val_loss: 0.5966 - val_accuracy: 0.8333
# Epoch 30/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5946 - accuracy: 0.7539 - val_loss: 0.5861 - val_accuracy: 0.8333
# Epoch 31/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5899 - accuracy: 0.7644 - val_loss: 0.5756 - val_accuracy: 0.8333
# Epoch 32/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5668 - accuracy: 0.7801 - val_loss: 0.5640 - val_accuracy: 0.8333
# Epoch 33/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.5780 - accuracy: 0.7644 - val_loss: 0.5536 - val_accuracy: 0.8333
# Epoch 34/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5548 - accuracy: 0.7906 - val_loss: 0.5429 - val_accuracy: 0.8333
# Epoch 35/1000
# 6/6 [==============================] - 0s 25ms/step - loss: 0.5643 - accuracy: 0.7696 - val_loss: 0.5328 - val_accuracy: 0.8333
# Epoch 36/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5602 - accuracy: 0.7487 - val_loss: 0.5241 - val_accuracy: 0.8333
# Epoch 37/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.5468 - accuracy: 0.7958 - val_loss: 0.5158 - val_accuracy: 0.8333
# Epoch 38/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.5244 - accuracy: 0.8063 - val_loss: 0.5074 - val_accuracy: 0.8333
# Epoch 39/1000
# 6/6 [==============================] - 0s 34ms/step - loss: 0.5438 - accuracy: 0.7696 - val_loss: 0.5009 - val_accuracy: 0.8333
# Epoch 40/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.5277 - accuracy: 0.7853 - val_loss: 0.4943 - val_accuracy: 0.8333
# Epoch 41/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.5183 - accuracy: 0.8010 - val_loss: 0.4873 - val_accuracy: 0.8333
# Epoch 42/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.5087 - accuracy: 0.7906 - val_loss: 0.4815 - val_accuracy: 0.8333
# Epoch 43/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4886 - accuracy: 0.7749 - val_loss: 0.4767 - val_accuracy: 0.8333
# Epoch 44/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4889 - accuracy: 0.8010 - val_loss: 0.4712 - val_accuracy: 0.8333
# Epoch 45/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5595 - accuracy: 0.7173 - val_loss: 0.4679 - val_accuracy: 0.8333
# Epoch 46/1000
# 6/6 [==============================] - 0s 28ms/step - loss: 0.5022 - accuracy: 0.7696 - val_loss: 0.4636 - val_accuracy: 0.8333
# Epoch 47/1000
# 6/6 [==============================] - 0s 17ms/step - loss: 0.4972 - accuracy: 0.7853 - val_loss: 0.4614 - val_accuracy: 0.8125
# Epoch 48/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.5278 - accuracy: 0.8010 - val_loss: 0.4586 - val_accuracy: 0.7917
# Epoch 49/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4791 - accuracy: 0.7958 - val_loss: 0.4561 - val_accuracy: 0.7917
# Epoch 50/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5029 - accuracy: 0.8010 - val_loss: 0.4533 - val_accuracy: 0.7917
# Epoch 51/1000
# 6/6 [==============================] - 0s 31ms/step - loss: 0.4921 - accuracy: 0.7906 - val_loss: 0.4512 - val_accuracy: 0.7917
# Epoch 52/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4873 - accuracy: 0.7539 - val_loss: 0.4496 - val_accuracy: 0.8125
# Epoch 53/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5005 - accuracy: 0.7749 - val_loss: 0.4476 - val_accuracy: 0.8125
# Epoch 54/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4657 - accuracy: 0.8063 - val_loss: 0.4445 - val_accuracy: 0.8125
# Epoch 55/1000
# 6/6 [==============================] - 0s 14ms/step - loss: 0.4652 - accuracy: 0.7958 - val_loss: 0.4414 - val_accuracy: 0.8125
# Epoch 56/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4674 - accuracy: 0.8115 - val_loss: 0.4384 - val_accuracy: 0.8333
# Epoch 57/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4764 - accuracy: 0.8010 - val_loss: 0.4366 - val_accuracy: 0.8333
# Epoch 58/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4668 - accuracy: 0.8115 - val_loss: 0.4355 - val_accuracy: 0.8333
# Epoch 59/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4741 - accuracy: 0.7906 - val_loss: 0.4346 - val_accuracy: 0.8125
# Epoch 60/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4763 - accuracy: 0.8115 - val_loss: 0.4329 - val_accuracy: 0.8125
# Epoch 61/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4629 - accuracy: 0.7906 - val_loss: 0.4321 - val_accuracy: 0.8125
# Epoch 62/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.4482 - accuracy: 0.8063 - val_loss: 0.4318 - val_accuracy: 0.8125
# Epoch 63/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.5054 - accuracy: 0.7382 - val_loss: 0.4319 - val_accuracy: 0.8125
# Epoch 64/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4708 - accuracy: 0.7906 - val_loss: 0.4305 - val_accuracy: 0.8125
# Epoch 65/1000
# 6/6 [==============================] - 0s 20ms/step - loss: 0.4711 - accuracy: 0.8010 - val_loss: 0.4292 - val_accuracy: 0.8125
# Epoch 66/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4349 - accuracy: 0.8168 - val_loss: 0.4288 - val_accuracy: 0.8125
# Epoch 67/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4416 - accuracy: 0.8168 - val_loss: 0.4280 - val_accuracy: 0.8125
# Epoch 68/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4534 - accuracy: 0.8063 - val_loss: 0.4256 - val_accuracy: 0.8333
# Epoch 69/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4562 - accuracy: 0.7958 - val_loss: 0.4234 - val_accuracy: 0.8542
# Epoch 70/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4417 - accuracy: 0.8168 - val_loss: 0.4207 - val_accuracy: 0.8333
# Epoch 71/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4563 - accuracy: 0.8063 - val_loss: 0.4185 - val_accuracy: 0.8333
# Epoch 72/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.5005 - accuracy: 0.8010 - val_loss: 0.4169 - val_accuracy: 0.8333
# Epoch 73/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4561 - accuracy: 0.8377 - val_loss: 0.4166 - val_accuracy: 0.8333
# Epoch 74/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4744 - accuracy: 0.7749 - val_loss: 0.4160 - val_accuracy: 0.8333
# Epoch 75/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4668 - accuracy: 0.8272 - val_loss: 0.4150 - val_accuracy: 0.8125
# Epoch 76/1000
# 6/6 [==============================] - 0s 22ms/step - loss: 0.4775 - accuracy: 0.7958 - val_loss: 0.4129 - val_accuracy: 0.8125
# Epoch 77/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4855 - accuracy: 0.7906 - val_loss: 0.4109 - val_accuracy: 0.8125
# Epoch 78/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4818 - accuracy: 0.7853 - val_loss: 0.4096 - val_accuracy: 0.8333
# Epoch 79/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4764 - accuracy: 0.7906 - val_loss: 0.4089 - val_accuracy: 0.8125
# Epoch 80/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4142 - accuracy: 0.8429 - val_loss: 0.4086 - val_accuracy: 0.8333
# Epoch 81/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4693 - accuracy: 0.8168 - val_loss: 0.4082 - val_accuracy: 0.8333
# Epoch 82/1000
# 6/6 [==============================] - 0s 12ms/step - loss: 0.4354 - accuracy: 0.8010 - val_loss: 0.4081 - val_accuracy: 0.8333
# Epoch 83/1000
# 6/6 [==============================] - 0s 8ms/step - loss: 0.4831 - accuracy: 0.7906 - val_loss: 0.4079 - val_accuracy: 0.8333
# Epoch 84/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.5097 - accuracy: 0.7958 - val_loss: 0.4082 - val_accuracy: 0.8333
# Epoch 85/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4489 - accuracy: 0.8115 - val_loss: 0.4086 - val_accuracy: 0.8333
# Epoch 86/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4366 - accuracy: 0.8063 - val_loss: 0.4084 - val_accuracy: 0.8333
# Epoch 87/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4324 - accuracy: 0.8010 - val_loss: 0.4077 - val_accuracy: 0.8333
# Epoch 88/1000
# 6/6 [==============================] - 0s 10ms/step - loss: 0.4020 - accuracy: 0.8377 - val_loss: 0.4070 - val_accuracy: 0.8333
# Epoch 89/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4751 - accuracy: 0.8010 - val_loss: 0.4068 - val_accuracy: 0.8125
# Epoch 90/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4276 - accuracy: 0.8482 - val_loss: 0.4072 - val_accuracy: 0.8333
# Epoch 91/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4248 - accuracy: 0.8429 - val_loss: 0.4067 - val_accuracy: 0.8333
# Epoch 92/1000
# 6/6 [==============================] - 0s 13ms/step - loss: 0.4386 - accuracy: 0.8325 - val_loss: 0.4065 - val_accuracy: 0.8333
# Epoch 93/1000
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4629 - accuracy: 0.8482 - val_loss: 0.4062 - val_accuracy: 0.8542
# Epoch 94/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4087 - accuracy: 0.8272 - val_loss: 0.4061 - val_accuracy: 0.8542
# Epoch 95/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4901 - accuracy: 0.8168 - val_loss: 0.4053 - val_accuracy: 0.8542
# Epoch 96/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4155 - accuracy: 0.8063 - val_loss: 0.4047 - val_accuracy: 0.8542
# Epoch 97/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4410 - accuracy: 0.8220 - val_loss: 0.4052 - val_accuracy: 0.8542
# Epoch 98/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4106 - accuracy: 0.8272 - val_loss: 0.4050 - val_accuracy: 0.8333
# Epoch 99/1000
# 6/6 [==============================] - 0s 16ms/step - loss: 0.3674 - accuracy: 0.8482 - val_loss: 0.4040 - val_accuracy: 0.8542
# Epoch 100/1000
# 6/6 [==============================] - 0s 45ms/step - loss: 0.4604 - accuracy: 0.8220 - val_loss: 0.4031 - val_accuracy: 0.8542
# Epoch 101/1000
# 6/6 [==============================] - 0s 24ms/step - loss: 0.4099 - accuracy: 0.8639 - val_loss: 0.4028 - val_accuracy: 0.8542
# Epoch 102/1000
# 6/6 [==============================] - 0s 18ms/step - loss: 0.3682 - accuracy: 0.8429 - val_loss: 0.4027 - val_accuracy: 0.8542
# Epoch 103/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4239 - accuracy: 0.8220 - val_loss: 0.4021 - val_accuracy: 0.8542
# Epoch 104/1000
# 6/6 [==============================] - 0s 18ms/step - loss: 0.4019 - accuracy: 0.8848 - val_loss: 0.4016 - val_accuracy: 0.8542
# Epoch 105/1000
# 6/6 [==============================] - 0s 26ms/step - loss: 0.4574 - accuracy: 0.8115 - val_loss: 0.4016 - val_accuracy: 0.8333
# Epoch 106/1000
# 6/6 [==============================] - 0s 11ms/step - loss: 0.4495 - accuracy: 0.8168 - val_loss: 0.4018 - val_accuracy: 0.8333
# Epoch 107/1000
# 6/6 [==============================] - 0s 15ms/step - loss: 0.4463 - accuracy: 0.8482 - val_loss: 0.4029 - val_accuracy: 0.8333
# Epoch 108/1000
# 6/6 [==============================] - 0s 21ms/step - loss: 0.4672 - accuracy: 0.8010 - val_loss: 0.4034 - val_accuracy: 0.8333
# Epoch 109/1000
# 6/6 [==============================] - 0s 9ms/step - loss: 0.4487 - accuracy: 0.8115 - val_loss: 0.4036 - val_accuracy: 0.8333
# Epoch 110/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4016 - accuracy: 0.8325 - val_loss: 0.4031 - val_accuracy: 0.8333
# Epoch 111/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4315 - accuracy: 0.8325 - val_loss: 0.4023 - val_accuracy: 0.8333
# Epoch 112/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4391 - accuracy: 0.8377 - val_loss: 0.4020 - val_accuracy: 0.8333
# Epoch 113/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4118 - accuracy: 0.8429 - val_loss: 0.4018 - val_accuracy: 0.8333
# Epoch 114/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3956 - accuracy: 0.8534 - val_loss: 0.4029 - val_accuracy: 0.8333
# Epoch 115/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3969 - accuracy: 0.8325 - val_loss: 0.4036 - val_accuracy: 0.8333
# Epoch 116/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4179 - accuracy: 0.8482 - val_loss: 0.4031 - val_accuracy: 0.8333
# Epoch 117/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4366 - accuracy: 0.8220 - val_loss: 0.4037 - val_accuracy: 0.8333
# Epoch 118/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.3893 - accuracy: 0.8377 - val_loss: 0.4041 - val_accuracy: 0.8333
# Epoch 119/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4282 - accuracy: 0.8115 - val_loss: 0.4038 - val_accuracy: 0.8333
# Epoch 120/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4160 - accuracy: 0.8168 - val_loss: 0.4040 - val_accuracy: 0.8333
# Epoch 121/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4029 - accuracy: 0.8010 - val_loss: 0.4043 - val_accuracy: 0.8333
# Epoch 122/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4422 - accuracy: 0.8325 - val_loss: 0.4045 - val_accuracy: 0.8333
# Epoch 123/1000
# 6/6 [==============================] - 0s 6ms/step - loss: 0.4527 - accuracy: 0.8168 - val_loss: 0.4047 - val_accuracy: 0.8125
# Epoch 124/1000
# 6/6 [==============================] - 0s 7ms/step - loss: 0.4170 - accuracy: 0.8272 - val_loss: 0.4054 - val_accuracy: 0.8125

# %%
val_accuracy = np.mean(history.history['val_accuracy'])
print("\n%s: %.2f%%" % ('val_accuracy', val_accuracy*100))
# Out:
# val_accuracy: 80.14%

# %% [markdown]
# **Plotting training and validation loss over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['loss']], "#6daa9f", label='Training loss')
plt.plot(history_df.loc[:, ['val_loss']],"#774571", label='Validation loss')
plt.title('Training and Validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend(loc="best")

plt.show()

# %% [markdown]
# **Plotting training and validation accuracy over epochs**

# %%
history_df = pd.DataFrame(history.history)

plt.plot(history_df.loc[:, ['accuracy']], "#6daa9f", label='Training accuracy')
plt.plot(history_df.loc[:, ['val_accuracy']], "#774571", label='Validation accuracy')

plt.title('Training and Validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %% [markdown]
# # **<span style="color:#6daa9f;">CONCLUSIONS</span>**
#
# **Concluding the model with:**
#
# * Testing on the test set
# * Evaluating the confusion matrix
# * Evaluating the classification report

# %%
# Predicting the test set results
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
np.set_printoptions()
# Out:
# 2/2 [==============================] - 0s 5ms/step

# %%
# confusion matrix
cmap1 = sns.diverging_palette(275,150,  s=40, l=65, n=6)
plt.subplots(figsize=(12,8))
cf_matrix = confusion_matrix(y_test, y_pred)
sns.heatmap(cf_matrix/np.sum(cf_matrix), cmap = cmap1, annot = True, annot_kws = {'size':15})

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.89      0.89        46
#            1       0.64      0.64      0.64        14
#
#     accuracy                           0.83        60
#    macro avg       0.77      0.77      0.77        60
# weighted avg       0.83      0.83      0.83        60

# %% [markdown]
# Thanks for revieving the project.
#
# 194410021 Arman
